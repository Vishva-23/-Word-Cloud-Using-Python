# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishva-23/-Word-Cloud-Using-Python/blob/main/WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import re
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

#pip install wordcloud
from wordcloud import WordCloud

# %%
import nltk

# %%
with open('MyFav.txt','r') as f:
    text = f.readlines()

# %%
text = [line.strip() for line in text]
print(text)
# Out:
# ["Movies have always held a special place in my heart, and over the years, they have become more than just a form of entertainment for me. They have turned into a full-fledged hobby that I am truly passionate about. With each film I watch, I delve into a new world, explore different cultures, and gain valuable insights into the human experience. One aspect of movies that captivates me is the power of storytelling. Whether it's a heartwarming drama, a thrilling action flick, or a thought-provoking documentary, movies have the ability to transport me to different times and places. I am constantly amazed by the creativity and imagination of filmmakers who can weave together compelling narratives, create complex characters, and elicit a range of emotions from their audiences. It's truly an art form that I deeply admire. Furthermore, movies offer a window into different cultures and perspectives. Through foreign films, I have been able to immerse myself in the customs, traditions, and values of diverse societies. It has broadened my understanding of the world and deepened my appreciation for the richness of human experiences. I believe that movies have the power to bridge gaps and foster empathy by exposing us to different viewpoints and challenging our preconceived notions. In addition to being a viewer, I also enjoy analyzing and discussing films. I find great joy in dissecting the various elements of a movie, such as the cinematography, screenplay, performances, and underlying themes. Engaging in conversations with fellow movie enthusiasts allows me to gain new perspectives and insights, and it enhances my overall movie-watching experience. Lastly, movies serve as a source of inspiration for me. They ignite my creativity and fuel my imagination. As I watch extraordinary stories unfold on the screen, I am motivated to pursue my own creative endeavors and explore new avenues of self-expression. Whether it's writing, photography, or even filmmaking itself, movies have influenced my own artistic pursuits and have encouraged me to push boundaries. In conclusion, my hobby of watching movies goes beyond mere entertainment. It is an immersive experience that allows me to explore different worlds, cultures, and perspectives. Movies have the power to captivate, inspire, and broaden our horizons. Through storytelling and the magic of cinema, I continue to cherish this hobby and the profound impact it has on my life."]

# %%
#Vector of words and apply paster function into it
a = ['Hello', 'World', 'My', 'First','Handshake', 'Through', 'R']

# %%
a
# Out:
# ['Hello', 'World', 'My', 'First', 'Handshake', 'Through', 'R']

# %%
b= ' '.join(a)

# %%
b
# Out:
# 'Hello World My First Handshake Through R'

# %%
with open('MyFav.txt','r') as f:
    chunk_2 = f.readlines()

# %%
chunk_2= [line.strip() for line in text]

# %%
print(chunk_2)
# Out:
# ["Movies have always held a special place in my heart, and over the years, they have become more than just a form of entertainment for me. They have turned into a full-fledged hobby that I am truly passionate about. With each film I watch, I delve into a new world, explore different cultures, and gain valuable insights into the human experience. One aspect of movies that captivates me is the power of storytelling. Whether it's a heartwarming drama, a thrilling action flick, or a thought-provoking documentary, movies have the ability to transport me to different times and places. I am constantly amazed by the creativity and imagination of filmmakers who can weave together compelling narratives, create complex characters, and elicit a range of emotions from their audiences. It's truly an art form that I deeply admire. Furthermore, movies offer a window into different cultures and perspectives. Through foreign films, I have been able to immerse myself in the customs, traditions, and values of diverse societies. It has broadened my understanding of the world and deepened my appreciation for the richness of human experiences. I believe that movies have the power to bridge gaps and foster empathy by exposing us to different viewpoints and challenging our preconceived notions. In addition to being a viewer, I also enjoy analyzing and discussing films. I find great joy in dissecting the various elements of a movie, such as the cinematography, screenplay, performances, and underlying themes. Engaging in conversations with fellow movie enthusiasts allows me to gain new perspectives and insights, and it enhances my overall movie-watching experience. Lastly, movies serve as a source of inspiration for me. They ignite my creativity and fuel my imagination
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
stop_words = set(stopwords.words("english"))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
# removing using function removeWords()
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tokens = word_tokenize(clean_data3)
clean_data4 = [i for i in tokens if not i in stop_words]
clean_data4
# Out:
# ['movies',
#  'always',
#  'held',
#  'special',
#  'place',
#  'heart',
#  'years',
#  'become',
#  'form',
#  'entertainment',
#  'turned',
#  'fullfledged',
#  'hobby',
#  'truly',
#  'passionate',
#  'film',
#  'watch',
#  'delve',
#  'new',
#  'world',
#  'explore',
#  'different',
#  'cultures',
#  'gain',
#  'valuable',
#  'insights',
#  'human',
#  'experience',
#  'one',
#  'aspect',
#  'movies',
#  'captivates',
#  'power',
#  'storytelling',
#  'whether',
#  'heartwarming',
#  'drama',
#  'thrilling',
#  'action',
#  'flick',
#  'thoughtprovoking',
#  'documentary',
#  'movies',
#  'ability',
#  'transport',
#  'different',
#  'times',
#  'places',
#  'constantly',
#  'amazed',
#  'creativity',
#  'imagination',
#  'filmmakers',
#  'weave',
#  'together',
#  'compelling',
#  'narratives',
#  'create',
#  'complex',
#  'characters',
#  'elicit',
#  'range',
#  'emotions',
#  'audiences',
#  'truly',
#  'art',
#  'form',
#  'deeply',
#  'admire',
#  'furthermore',
#  'movies',
#  'offer',
#  'window',
#  'different',
#  'cultures',
#  'perspectives',
#  'foreign',
#  'films',
#  'able',
#  'immerse',
#  'customs',
#  'traditions',
#  'values',
#  'diverse',
#  'societies',
#  'broadened',
#  'understanding',
#  'world',
#  'deepened',
#  'appreciation',
#  'richness',
#  'human',
#  'experiences',
#  'believe',
#  'movies',
#  'power',
#  'bridge',
#  'gaps',
#  'foster',
#  'empathy',
#  'exposing',
#  'us',
#  'different',
#  'viewpoints',
#  'challenging',
#  'preconceived',
#  'notions',
#  'addition',
#  'viewer',
#  'also',
#  'enjoy',
#  'analyzing',
#  'discussing',
#  'films',
#  'find',
#  'great',
#  'joy',
#  'dissecting',
#  'various',
#  'elements',
#  'movie',
#  'cinematography',
#  'screenplay',
#  'performances',
#  'underlying',
#  'themes',
#  'engaging',
#  'conversations',
#  'fellow',
#  'movie',
#  'enthusiasts',
#  'allows',
#  'gain',
#  'new',
#  'perspectives',
#  'insights',
#  'enhances',
#  'overall',
#  'moviewatching',
#  'experience',
#  'lastly',
#  'movies',
#  'serve',
#  'source',
#  'inspiration',
#  'ignite',
#  'creativity',
#  'fuel',
#  'imagination',
#  'watch',
#  'extraordinary',
#  'stories',
#  'unfold',
#  'screen',
#  'motivated',
#  'pursue',
#  'creative',
#  'endeavors',
#  'explore',
#  'new',
#  'avenues',
#  'selfexpression',
#  'whether',
#  'writing',
#  'photography',
#  'even',
#  'filmmaking',
#  'movies',
#  'influenced',
#  'artistic',
#  'pursuits',
#  'encouraged',
#  'push',
#  'boundaries',
#  'conclusion',
#  'hobby',
#  'watching',
#  'movies',
#  'goes',
#  'beyond',
#  'mere',
#  'entertainment',
#  'immersive',
#  'experience',
#  'allows',
#  'explore',
#  'different',
#  'worlds',
#  'cultures',
#  'perspectives',
#  'movies',
#  'power',
#  'captivate',
#  'inspire',
#  'broaden',
#  'horizons',
#  'storytelling',
#  'magic',
#  'cinema',
#  'continue',
#  'cherish',
#  'hobby',
#  'profound',
#  'impact',
#  'life']

# %%
####Frequency of the Words ##########
words_dict = {}
for word in clean_data6.split():
    words_dict[word] = words_dict.get(word, 0)+1
for key in sorted (words_dict):
    print("{}:{}". format(key, words_dict[key]))
# Out:
# ability:1
# able:1
# action:1
# addition:1
# admire:1
# allows:2
# also:1
# always:1
# amazed:1
# analyzing:1
# appreciation:1
# art:1
# artistic:1
# aspect:1
# audiences:1
# avenues:1
# become:1
# believe:1
# beyond:1
# boundaries:1
# bridge:1
# broaden:1
# broadened:1
# captivate:1
# captivates:1
# challenging:1
# characters:1
# cherish:1
# cinema:1
# cinematography:1
# compelling:1
# complex:1
# conclusion:1
# constantly:1
# continue:1
# conversations:1
# create:1
# creative:1
# creativity:2
# cultures:3
# customs:1
# deepened:1
# deeply:1
# delve:1
# different:5
# discussing:1
# dissecting:1
# diverse:1
# documentary:1
# drama:1
# elements:1
# elicit:1
# emotions:1
# empathy:1
# encouraged:1
# endeavors:1
# engaging:1
# enhances:1
# enjoy:1
# entertainment:2
# enthusiasts:1
# even:1
# experience:3
# experiences:1
# explore:3
# exposing:1
# extraordinary:1
# fellow:1
# film:1
# filmmakers:1
# filmmaking:1
# films:2
# find:1
# flick:1
# foreign:1
# form:2
# foster:1
# fuel:1
# fullfledged:1
# furthermore:1
# gain:2
# gaps:1
# goes:1
# great:1
# heart:1
# heartwarming:1
# held:1
# hobby:3
# horizons:1
# human:2
# ignite:1
# imagination:2
# immerse:1
# immersive:1
# impact:1
# influenced:1
# insights:2
# inspiration:1
# inspire:1
# joy:1
# lastly:1
# life:1
# magic:1
# mere:1
# motivated:1
# movie:2
# movies:9
# moviewatching:1
# narratives:1
# new:3
# notions:1
# offer:1
# one:1
# overall:1
# passionate:1
# performances:1
# perspectives:3
# photography:1
# place:1
# places:1
# power:3
# preconceived:1
# profound:1
# pursue:1
# pursuits:1
# push:1
# range:1
# richness:1
# screen:1
# screenplay:1
# selfexpression:1
# serve:1
# societies:1
# source:1
# special:1
# stories:1
# storytelling:2
# themes:1
# thoughtprovoking:1
# thrilling:1
# times:1
# together:1
# traditions:1
# transport:1
# truly:2
# turned:1
# underlying:1
# understanding:1
# unfold:1
# us:1
# valuable:1
# values:1
# various:1
# viewer:1
# viewpoints:1
# watch:2
# watching:1
# weave:1
# whether:2
# window:1
# world:2
# worlds:1
# writing:1
# years:1

# %%
#####Word cloud #####
# create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0).generate(clean_data6)
#Display the generated image:
plt.imshow(wordcloud, interpolation= 'bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %%
#controlling number of words
wordcloud= WordCloud(width=480, height=480, max_words=3).generate(clean_data6)
plt.figure()
plt.imshow(wordcloud, interpolation= 'bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %%
wordcloud= WordCloud(width=480, height=480, colormap='Oranges_r').generate(clean_data6)
plt.figure()
plt.imshow(wordcloud, interpolation= 'bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %%
#Sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
analyser = SentimentIntensityAnalyzer()
scores = analyser.polarity_scores(clean_data6)
for key in sorted(scores):
    print('{0}:{1},'.format(key, scores[key]), end='')
# Out:
# compound:0.9981,neg:0.008,neu:0.634,pos:0.358,
